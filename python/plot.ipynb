# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import main_info
from scipy.optimize import curve_fit

# %%
def read_mat(path):
    f = open(path)
    lines = f.readlines()
    x, y = 0, 0
    mat = torch.zeros((128, 128))
    for l in lines:
        le = l.strip('\n').split(' ')
        for s in le:
            if len(s) != 0:
                mat[x, y] = float(s)
                y += 1
        x += 1
        y = 0
    return mat

# %%
r_path, i_path = "../real_mat.txt", "../img_mat.txt"
real, img = read_mat(r_path), read_mat(i_path)
mat = torch.complex(real, img)
res = torch.fft.ifft2(mat)
res = torch.fft.ifftshift(res).abs().numpy()
# plt.subplot(2, 4, i + 1)
plt.imshow(res)
plt.colorbar()
plt.show()

# %% [markdown]
# 静态 pool 数据

# %%
# !/home/xzc/miniconda3/bin/python /home/xzc/MRI-Simulator-cpp/python/data_analysis.py
# Out:
# Figure(640x480)
# 1437.0958119731604 -4.193612535122651 0.0033591986032249846
# 984.9230995395233 -1.5076900460476854 0.0007945289058831768

# %%
import data_analysis
_, _ = data_analysis.eight_imgs_data()

# %% [markdown]
# 动态血流flowpool

# %%
r_path, i_path = "/home/xzc/MRI-Simulator-cpp/result/static_128/real_mat_0.txt", "/home/xzc/MRI-Simulator-cpp/result/static_128/img_mat_0.txt"
real, img = read_mat(r_path), read_mat(i_path)
mat = torch.complex(real, img)
plt.subplot(2,1,1)
plt.imshow(mat.abs().numpy())
plt.colorbar()
res = torch.fft.ifft2(mat)
res = torch.fft.ifftshift(res).abs().numpy()
# plt.subplot(2, 4, i + 1)
plt.subplot(2, 1, 2)
plt.imshow(res)
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 r_path, i_path = "result/static_128/real_mat_0.txt", "result/static_128/img_mat_0.txt"
# ----> 2 real, img = read_mat(r_path), read_mat(i_path)
#       3 mat = torch.complex(real, img)
#       4 plt.subplot(2,1,1)
#
# Cell In[2], line 2, in read_mat(path)
#       1 def read_mat(path):
# ----> 2     f = open(path)
#       3     lines = f.readlines()
#       4     x, y = 0, 0
#
# File ~/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'result/static_128/real_mat_0.txt'

# %%
# !/home/xzc/miniconda3/bin/python /home/xzc/MRI-Simulator-cpp/python/data_analysis.py
# Out:
# 1436.2816219191598 -4.247891872056023 0.0046330753994892025
# 984.9237255675911 -1.5076274432408907 0.0005941899445591806

# %%
import data_analysis
_, _ = data_analysis.eight_imgs_data('/home/xzc/MRI-Simulator-cpp/result/flow_128/')
